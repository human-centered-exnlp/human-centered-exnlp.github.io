# %%
#!/usr/bin/python3
import os
import sys
import pandas as pd



def write_html(content, dirname):
#     print("content:", content)
    fileout = open(dirname, "w")
    fileout.writelines(content)
#     fileout.write(content)
    fileout.close()
    
def csv2html_converter(table, df, fileout, dirout):
    """
    Input: .csv file
    Output: 1) form.html; 2) quotes files.
    """

    # Create the table's column headers

    header = list(df.head(0))
    table += "  <thead>\n"
    table += "    <th init-sort>ID</th>\n"
    for column in header:
        if not column == "Paper URL":
            table += "    <th>{0}</th>\n".format(column.strip())
    table += "  </thead>\n"


    # Create the table's row data
    for r in range(len(df)):
        row = list(df.iloc[r])
        table += "<tbody>"
        table += "  <tr>\n"
        table += "    <td>{0}</td>\n".format(r+1)
        table += "    <td><a href='{}'>{}</a></td>\n".format(row[3], row[0])
        table += "    <td>{0}</td>\n".format(row[1])
        table += "    <td>{0}</td>\n".format(row[2])
        for col in range(4, len(row)):
            if row[col] != 0:
                write_html(row[col], os.path.join(dirout, f"{r+1}-{col}.html"))
#                 table += "    <td>{0}</td>\n".format(row[col])
                table += "    <td>{}<a class='page-link' href='/assets/files/form_quotes/{}-{}.html'>Quote</a>".format('{% include _icons/users.html %}', r+1, col)
#             else:
#                 table += "    <td>{0}</td>\n".format(row[col])
        table += "</tbody>"
        table += "  </tr>\n"

        
    table += "</table>"
    print("table:", table)

    fileout.writelines(table)
    
    fileout.close()

# %%
df=pd.read_csv('xai_forms.csv', sep=',').fillna(0)
fileout = open("../src/forms.html", "w")
dirout = "../assets/files/form_quotes"

heads = (
    "---\n"
    "layout: default\n"
    "---\n"
    "\n\n\n"
    "<head>\n"
      "  <link rel='stylesheet' href='https://cdnjs.cloudflare.com/ajax/libs/sortable/0.8.0/css/sortable-theme-bootstrap.min.css' />\n"
      "  <script src='https://cdnjs.cloudflare.com/ajax/libs/sortable/0.8.0/js/sortable.min.js'></script>\n"
      "  <script type='text/javascript' src='https://cdn.rawgit.com/pcooksey/bibtex-js/ef59e62c/src/bibtex_js.js'></script>\n"
      "  <bibtex src='references.bib'></bibtex>\n"
      "  <link rel='stylesheet' href='/assets/css/main.css'>\n"
    "</head>"
    "\n\n\n"

    "<script type='text/javascript'>\n"
      "  var table = document.querySelectorAll('table[data-sortable]')[0]\n"
      "  Sortable.initTable(table)\n"

      "  var initSortCol = document.querySelectorAll('table[data-sortable] > thead > tr > th[init-sort]')\n"
      "  if (initSortCol.length > 0) {\n"
      "    initSortCol[0].click()\n"
      "  }\n"

      "  function myFunction(variable) {\n"
      "    var myWindow = window.open('Quotes', variable, 'width=600, height=600');\n"
      "    myWindow.document.write('<p>'+myWindow.name+'</p>');\n"
      "  }\n"
    "</script>\n\n\n")


table = heads + "<table class='sortable-theme-bootstrap' data-sortable>\n"

csv2html_converter(table, df, fileout, dirout)

# %%
# Out:
# table: ---
# layout: default
# ---
#
#
#
# <head>
#   <link rel='stylesheet' href='https://cdnjs.cloudflare.com/ajax/libs/sortable/0.8.0/css/sortable-theme-bootstrap.min.css' />
#   <script src='https://cdnjs.cloudflare.com/ajax/libs/sortable/0.8.0/js/sortable.min.js'></script>
#   <script type='text/javascript' src='https://cdn.rawgit.com/pcooksey/bibtex-js/ef59e62c/src/bibtex_js.js'></script>
#   <bibtex src='references.bib'></bibtex>
#   <link rel='stylesheet' href='/assets/css/main.css'>
# </head>
#
#
# <script type='text/javascript'>
#   var table = document.querySelectorAll('table[data-sortable]')[0]
#   Sortable.initTable(table)
#   var initSortCol = document.querySelectorAll('table[data-sortable] > thead > tr > th[init-sort]')
#   if (initSortCol.length > 0) {
#     initSortCol[0].click()
#   }
#   function myFunction(variable) {
#     var myWindow = window.open('Quotes', variable, 'width=600, height=600');
#     myWindow.document.write('<p>'+myWindow.name+'</p>');
#   }
# </script>
#
#
# <table class='sortable-theme-bootstrap' data-sortable>
#   <thead>
#     <th init-sort>ID</th>
#     <th>Title</th>
#     <th>Year</th>
#     <th>Venue</th>
#     <th>Feature Importanc (FIM)</th>
#     <th>Probing (PRB)</th>
#     <th>Tuple/Graph (TUP)</th>
#     <th>Space Map (SPM)</th>
#     <th>Rule/Grammar (RUL)</th>
#     <th>Free Text (FRT)</th>
#     <th>Concept/Sense (CPT)</th>
#     <th>Example (EXP)</th>
#     <th>Trigger (TRG)</th>
#     <th>Word Cloud (WCL)</th>
#     <th>Images (IMG)</th>
#     <th>Confidence Score (CFD)</th>
#   </thead>
# <tbody>  <tr>
#     <td>1</td>
#     <td><a href='https://www.aclweb.org/anthology/W18-5306/'>AttentionMeSH: Simple, Effective and Interpretable Automatic MeSH Indexer</a></td>
#     <td>2018</td>
#     <td>Proceedings of the 6th BioASQ Workshop A challenge on large-scale biomedical semantic indexing and question answering</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/1-4.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>2</td>
#     <td><a href='https://arxiv.org/pdf/1909.11218.pdf'>Attention interpretability across nlp tasks</a></td>
#     <td>2019</td>
#     <td>Arxiv</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/2-4.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>3</td>
#     <td><a href='https://www.aclweb.org/anthology/P19-1282.pdf'>Is attention interpretable?</a></td>
#     <td>2019</td>
#     <td>ACL</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/3-4.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>4</td>
#     <td><a href='https://arxiv.org/pdf/1902.10186.pdf'>Attention is not Explanation</a></td>
#     <td>2019</td>
#     <td>NAACL</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/4-4.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>5</td>
#     <td><a href='https://www.aclweb.org/anthology/D19-1002.pdf'>Attention is not not Explanation</a></td>
#     <td>2019</td>
#     <td>EMNLP</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/5-4.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>6</td>
#     <td><a href='https://arxiv.org/pdf/2004.14243.pdf'>Towards Transparent and Explainable Attention Models</a></td>
#     <td>2020</td>
#     <td>ACL</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/6-4.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>7</td>
#     <td><a href='https://www.aclweb.org/anthology/D19-1017.pdf'>Interpretable Relevant Emotion Ranking with Event-Driven Attention</a></td>
#     <td>2019</td>
#     <td>EMNLP</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/7-4.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>8</td>
#     <td><a href='https://www.aclweb.org/anthology/2020.lrec-1.220.pdf'>Why Attention is Not Explanation: Surgical Intervention and Causal Reasoning about Neural Models</a></td>
#     <td>2020</td>
#     <td>LREC</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/8-4.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>9</td>
#     <td><a href='https://www.aclweb.org/anthology/W19-4808.pdf'>Analyzing the Structure of Attention in a Transformer Language Model</a></td>
#     <td>2019</td>
#     <td>BlackboxNLP</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/9-4.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>10</td>
#     <td><a href='https://www.aclweb.org/anthology/2020.blackboxnlp-1.14.pdf'>The elephant in the interpretability room: Why use attention as explanation when we have saliency methods?</a></td>
#     <td>2020</td>
#     <td>BlackboxNLP</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/10-4.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>11</td>
#     <td><a href='https://www.aclweb.org/anthology/P19-1570.pdf'>Word2Sense: sparse interpretable word embeddings</a></td>
#     <td>2019</td>
#     <td>ACL</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/11-10.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>12</td>
#     <td><a href='https://www.aclweb.org/anthology/D19-1111.pdf'>Analytical methods for interpretable ultradense word embeddings</a></td>
#     <td>2019</td>
#     <td>EMNLP</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/12-10.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>13</td>
#     <td><a href='https://www.aclweb.org/anthology/D19-1627.pdf'>What does this word mean? explaining contextualized embeddings with natural language definition</a></td>
#     <td>2019</td>
#     <td>EMNLP</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/13-10.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>14</td>
#     <td><a href='https://www.aclweb.org/anthology/W19-2102.pdf'>Identification, interpretability, and Bayesian word embeddings</a></td>
#     <td>2019</td>
#     <td>NAACL</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/14-10.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>15</td>
#     <td><a href='https://www.aclweb.org/anthology/D19-1661.pdf'>Interpretable Word Embeddings via Informative Priors</a></td>
#     <td>2019</td>
#     <td>EMNLP</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/15-10.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>16</td>
#     <td><a href='https://www.aclweb.org/anthology/W19-2001.pdf'>Neural vector conceptualization for word vector space interpretation</a></td>
#     <td>2019</td>
#     <td>NAACL</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/16-10.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>17</td>
#     <td><a href='https://www.aclweb.org/anthology/2020.acl-main.431.pdf'>Interpreting Pretrained Contextualized Representations via Reductions to Static Embeddings</a></td>
#     <td>2020</td>
#     <td>ACL</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/17-10.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>18</td>
#     <td><a href='https://arxiv.org/pdf/1711.08792.pdf'>SPINE: SParse Interpretable Neural Embeddings</a></td>
#     <td>2018</td>
#     <td>AAAI</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/18-10.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>19</td>
#     <td><a href='https://arxiv.org/pdf/1905.10650.pdf'>Are sixteen heads really better than one?</a></td>
#     <td>2019</td>
#     <td>NeuIPS</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/19-4.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>20</td>
#     <td><a href='https://arxiv.org/pdf/1907.13528.pdf'>What BERT is not: Lessons from a new suite of psycholinguistic diagnostics for language models</a></td>
#     <td>2020</td>
#     <td>TACL</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/20-5.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>21</td>
#     <td><a href='https://arxiv.org/pdf/1911.01485.pdf'>Assessing social and intersectional biases in contextualized word representations</a></td>
#     <td>2019</td>
#     <td>NeuIPS</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/21-5.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>22</td>
#     <td><a href='https://arxiv.org/pdf/1909.00512.pdf'>How contextual are contextualized word representations? Comparing the geometry of BERT, ELMo, and GPT-2 embeddings</a></td>
#     <td>2019</td>
#     <td>EMNLP-IJCNLP</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/22-5.html'>Quote</a>    <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/22-7.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>23</td>
#     <td><a href='https://www.aclweb.org/anthology/N19-1419.pdf'>A structural probe for finding syntax in word representations</a></td>
#     <td>2019</td>
#     <td>NAACL</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/23-6.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>24</td>
#     <td><a href='https://www.aclweb.org/anthology/D19-1221.pdf'>Universal adversarial triggers for attacking and analyzing NLP</a></td>
#     <td>2019</td>
#     <td>EMNLP-IJCNLP</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/24-9.html'>Quote</a>    <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/24-12.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>25</td>
#     <td><a href='https://www.aclweb.org/anthology/2020.acl-main.190.pdf'>ExpBERT: Representation Engineering with Natural Language Explanations</a></td>
#     <td>2020</td>
#     <td>ACL</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/25-8.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>26</td>
#     <td><a href='https://arxiv.org/pdf/2004.14786.pdf'>Perturbed Masking: Parameter-free Probing for Analyzing and Interpreting BERT</a></td>
#     <td>2020</td>
#     <td>ACL</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/26-5.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>27</td>
#     <td><a href='https://arxiv.org/pdf/2010.06775.pdf'>Vokenization: Improving Language Understanding with Contextualized, Visual-Grounded Supervision</a></td>
#     <td>2020</td>
#     <td>EMNLP</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/27-14.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>28</td>
#     <td><a href='https://www.aclweb.org/anthology/W19-4825.pdf'>Open Sesame: Getting Inside BERT's Linguistic Knowledge</a></td>
#     <td>2019</td>
#     <td>BlackboxNLP</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/28-5.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>29</td>
#     <td><a href='https://arxiv.org/pdf/1906.04341.pdf'>What does bert look at? an analysis of bert's attention</a></td>
#     <td>2019</td>
#     <td>BlackboxNLP</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/29-5.html'>Quote</a>    <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/29-6.html'>Quote</a>    <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/29-7.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>30</td>
#     <td><a href='https://arxiv.org/pdf/2002.12327.pdf'>A primer in bertology: What we know about how bert works</a></td>
#     <td>2020</td>
#     <td>TACL</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/30-4.html'>Quote</a>    <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/30-6.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>31</td>
#     <td><a href='https://www.aclweb.org/anthology/P19-1356.pdf'>What Does BERT Learn about the Structure of Language?</a></td>
#     <td>2019</td>
#     <td>ACL</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/31-5.html'>Quote</a>    <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/31-6.html'>Quote</a>    <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/31-7.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>32</td>
#     <td><a href='https://www.aclweb.org/anthology/P19-1452.pdf'>BERT Rediscovers the Classical NLP Pipeline</a></td>
#     <td>2019</td>
#     <td>ACL</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/32-5.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>33</td>
#     <td><a href='https://arxiv.org/pdf/1908.05620.pdf'>Visualizing and Understanding the Effectiveness of BERT</a></td>
#     <td>2019</td>
#     <td>EMNLP-IJCNLP</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/33-7.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>34</td>
#     <td><a href='https://arxiv.org/pdf/1810.09648.pdf'>What can AI do for me? evaluating machine learning interpretations in cooperative play</a></td>
#     <td>2019</td>
#     <td>IUI</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/34-4.html'>Quote</a>    <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/34-11.html'>Quote</a>    <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/34-15.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>35</td>
#     <td><a href='https://arxiv.org/pdf/1804.07781.pdf'>Pathologies of Neural Models Make Interpretations Difficult</a></td>
#     <td>2018</td>
#     <td>EMNLP</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/35-4.html'>Quote</a>    <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/35-12.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>36</td>
#     <td><a href='https://arxiv.org/pdf/1911.03429.pdf'>Eraser: A benchmark to evaluate rationalized nlp models</a></td>
#     <td>2020</td>
#     <td>ACL</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/36-4.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>37</td>
#     <td><a href='https://www.aclweb.org/anthology/2020.acl-main.386.pdf'>Towards Faithfully Interpretable NLP Systems: How should we define and evaluate faithfulness?</a></td>
#     <td>2020</td>
#     <td>ACL</td>
# </tbody>  </tr>
# <tbody>  <tr>
#     <td>38</td>
#     <td><a href='https://www.aclweb.org/anthology/2020.acl-main.491.pdf'>Evaluating Explainable AI: Which Algorithmic Explanations Help Users Predict Model Behavior?</a></td>
#     <td>2020</td>
#     <td>ACL</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/38-8.html'>Quote</a>    <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/38-11.html'>Quote</a>    <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/38-15.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>39</td>
#     <td><a href='https://www.aclweb.org/anthology/2020.acl-main.495.pdf'>Obtaining Faithful Interpretations from Compositional Neural Networks</a></td>
#     <td>2020</td>
#     <td>ACL</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/39-8.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>40</td>
#     <td><a href='https://www.aclweb.org/anthology/2020.acl-main.419.pdf'>Human Attention Maps for Text Classification: Do Humans and Neural Networks Focus on the Same Words?</a></td>
#     <td>2020</td>
#     <td>ACL</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/40-4.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>41</td>
#     <td><a href='https://www.aclweb.org/anthology/D16-1092.pdf'>Human Attention in Visual Question Answering: Do Humans and Deep Networks look at the same regions?</a></td>
#     <td>2016</td>
#     <td>EMNLP</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/41-4.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>42</td>
#     <td><a href='https://www.aclweb.org/anthology/N18-1097.pdf'>Comparing Automatic and Human Evaluation of Local Explanations for Text Classification</a></td>
#     <td>2018</td>
#     <td>NAACL</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/42-4.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>43</td>
#     <td><a href='https://arxiv.org/pdf/1711.07414v1.pdf'>The Promise and Peril of Human Evaluation for Model Interpretability</a></td>
#     <td>2019</td>
#     <td>0</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/43-7.html'>Quote</a>    <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/43-9.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>44</td>
#     <td><a href='https://arxiv.org/pdf/2010.04736.pdf'>Evaluating and Characterizing Human Rationales</a></td>
#     <td>2020</td>
#     <td>EMNLP</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/44-4.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>45</td>
#     <td><a href='https://arxiv.org/pdf/2009.13295.pdf'>A Diagnostic Study of Explainability Techniques for Text Classification</a></td>
#     <td>2020</td>
#     <td>EMNLP</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/45-4.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>46</td>
#     <td><a href='https://homes.cs.washington.edu/~weld/papers/smith-renner-chi20.pdf'>No Explainability without Accountability: An Empirical Study of Explanations and Feedback in Interactive ML</a></td>
#     <td>2020</td>
#     <td>CHI</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/46-4.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>47</td>
#     <td><a href='https://www.aclweb.org/anthology/2020.acl-demos.42.pdf'>LEAN-LIFE: A Label-Efficient Annotation Framework Towards Learning from Explanation</a></td>
#     <td>2020</td>
#     <td>ACL</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/47-4.html'>Quote</a>    <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/47-6.html'>Quote</a>    <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/47-9.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>48</td>
#     <td><a href='https://openreview.net/pdf?id=rJlUt0EYwS'>Learning from Explanations with Neural Execution Tree</a></td>
#     <td>2020</td>
#     <td>ICLR</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/48-8.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>49</td>
#     <td><a href='https://www.aclweb.org/anthology/N07-1033.pdf'>Using “Annotator Rationales” to Improve Machine Learning for Text Categorization</a></td>
#     <td>2007</td>
#     <td>NAACL</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/49-4.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>50</td>
#     <td><a href='https://openaccess.city.ac.uk/id/eprint/13819/1/paper326.pdf'>Principles of Explanatory Debugging to Personalize Interactive Machine Learning</a></td>
#     <td>2015</td>
#     <td>IUI</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/50-4.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>51</td>
#     <td><a href='https://arxiv.org/pdf/1809.07424.pdf'>Towards Accountable AI: Hybrid Human-Machine Analyses for Characterizing System Failure</a></td>
#     <td>2018</td>
#     <td>HCOMP</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/51-6.html'>Quote</a>    <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/51-10.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>52</td>
#     <td><a href='https://arxiv.org/pdf/1908.05601.pdf'>Learning credible deep neural networks with rationale regularization</a></td>
#     <td>2019</td>
#     <td>ICDM</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/52-4.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>53</td>
#     <td><a href='https://arxiv.org/pdf/1910.13294.pdf'>Rethinking Cooperative Rationalization: Introspective Extraction and Complement Control</a></td>
#     <td>2019</td>
#     <td>EMNLP</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/53-4.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>54</td>
#     <td><a href='https://www.aclweb.org/anthology/D17-1161.pdf'>Joint Concept Learning and Semantic Parsing from Natural Language Explanations</a></td>
#     <td>2017</td>
#     <td>EMNLP</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/54-10.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>55</td>
#     <td><a href='https://www.aclweb.org/anthology/P18-1175.pdf'>Training Classifiers with Natural Language Explanations</a></td>
#     <td>2018</td>
#     <td>ACL</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/55-8.html'>Quote</a>    <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/55-9.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>56</td>
#     <td><a href='https://www.aclweb.org/anthology/W19-4807.pdf'>Do Human Rationales Improve Machine Explanations?</a></td>
#     <td>2019</td>
#     <td>BlackboxNLP</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/56-4.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>57</td>
#     <td><a href='https://arxiv.org/pdf/1606.07461.pdf'>Lstmvis: A tool for visual analysis of hidden state dynamics in recurrent neural networks</a></td>
#     <td>2017</td>
#     <td>IEEE transactions on visualization and computer graphics</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/57-4.html'>Quote</a>    <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/57-6.html'>Quote</a>    <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/57-7.html'>Quote</a>    <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/57-8.html'>Quote</a>    <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/57-11.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>58</td>
#     <td><a href='https://arxiv.org/pdf/1804.09299.pdf'>Seq2seq-vis: A visual debugging tool for sequence-to-sequence models</a></td>
#     <td>2018</td>
#     <td>IEEE transactions on visualization and computer graphics</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/58-4.html'>Quote</a>    <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/58-6.html'>Quote</a>    <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/58-7.html'>Quote</a>    <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/58-11.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>59</td>
#     <td><a href='https://www.aclweb.org/anthology/D19-3002.pdf'>Allennlp interpret: A framework for explaining predictions of nlp models</a></td>
#     <td>2019</td>
#     <td>EMNLP</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/59-4.html'>Quote</a>    <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/59-8.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>60</td>
#     <td><a href='https://arxiv.org/pdf/1910.05276.pdf'>exbert: A visual analysis tool to explore learned representations in transformers models</a></td>
#     <td>2020</td>
#     <td>ACL</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/60-4.html'>Quote</a>    <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/60-8.html'>Quote</a>    <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/60-11.html'>Quote</a>    <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/60-15.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>61</td>
#     <td><a href='https://arxiv.org/pdf/2009.07896.pdf'>Captum: A unified and generic model interpretability library for PyTorch</a></td>
#     <td>2020</td>
#     <td>Arxiv</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/61-4.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>62</td>
#     <td><a href='https://arxiv.org/pdf/2008.05122.pdf'>The Language Interpretability Tool: Extensible, Interactive Visualizations and Analysis for NLP Models</a></td>
#     <td>2020</td>
#     <td>EMNLP</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/62-4.html'>Quote</a>    <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/62-6.html'>Quote</a>    <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/62-7.html'>Quote</a>    <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/62-8.html'>Quote</a>    <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/62-9.html'>Quote</a>    <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/62-11.html'>Quote</a>    <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/62-15.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>63</td>
#     <td><a href='https://www.isi.edu/natural-language/mt/emnlp16-nmt-grammar.pdf'>Does String-Based Neural MT Learn Source Syntax?</a></td>
#     <td>2016</td>
#     <td>EMNLP</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/63-8.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>64</td>
#     <td><a href='https://www.aclweb.org/anthology/W19-1504.pdf'>Lightly-supervised representation learning with global interpretability</a></td>
#     <td>2019</td>
#     <td>NAACL</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/64-7.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>65</td>
#     <td><a href='https://www.aclweb.org/anthology/D18-1365.pdf'>Explaining Character-Aware Neural Networks for Word-Level Prediction: Do They Discover Linguistic Rules?</a></td>
#     <td>2018</td>
#     <td>EMNLP</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/65-4.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>66</td>
#     <td><a href='https://www.aclweb.org/anthology/W18-2702.pdf'>A Shared Attention Mechanism for Interpretation of Neural Automatic Post-Editing Systems</a></td>
#     <td>2018</td>
#     <td>ACL</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/66-4.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>67</td>
#     <td><a href='https://www.aclweb.org/anthology/W19-4805.pdf'>Multi-Granular Text Encoding for Self-Explaining Categorization</a></td>
#     <td>2019</td>
#     <td>ACL</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/67-4.html'>Quote</a>    <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/67-6.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>68</td>
#     <td><a href='https://www.aclweb.org/anthology/P18-1101.pdf'>Unsupervised Discrete Sentence Representation Learning for Interpretable Neural Dialog Generation</a></td>
#     <td>2018</td>
#     <td>ACL</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/68-10.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>69</td>
#     <td><a href='https://www.aclweb.org/anthology/D18-1233.pdf'>Interpretation of Natural Language Rules in Conversational Machine Reading</a></td>
#     <td>2018</td>
#     <td>EMNLP</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/69-8.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>70</td>
#     <td><a href='https://www.aclweb.org/anthology/P19-1081.pdf'>OpenDialKG: Explainable Conversational Reasoning with Attention-based Walks over Knowledge Graphs</a></td>
#     <td>2019</td>
#     <td>ACL</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/70-6.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>71</td>
#     <td><a href='https://arxiv.org/pdf/1906.01603.pdf'>Do Neural Dialog Systems Use the Conversation History Effectively? An Empirical Study</a></td>
#     <td>2019</td>
#     <td>ACL</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/71-12.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>72</td>
#     <td><a href='https://www.aclweb.org/anthology/D19-1187.pdf'>Knowledge Aware Conversation Generation with Explainable Reasoning over Augmented Graphs</a></td>
#     <td>2019</td>
#     <td>EMNLP</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/72-6.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>73</td>
#     <td><a href='https://www.aclweb.org/anthology/P19-1006.pdf'>Constructing Interpretive Spatio-Temporal Features for Multi-Turn Responses Selection</a></td>
#     <td>2019</td>
#     <td>ACL</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/73-4.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>74</td>
#     <td><a href='https://www.aclweb.org/anthology/W18-5419.pdf'>Analysing the potential of seq-to-seq models for incremental interpretation in task-oriented dialogue</a></td>
#     <td>2018</td>
#     <td>BlackboxNLP</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/74-4.html'>Quote</a>    <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/74-5.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>75</td>
#     <td><a href='https://arxiv.org/pdf/2006.08331.pdf'>Probing Neural Dialog Models for Conversational Understanding</a></td>
#     <td>2020</td>
#     <td>ACL-NLP4ConvAI</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/75-5.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>76</td>
#     <td><a href='https://arxiv.org/pdf/1909.03368.pdf'>Designing and Interpreting Probes with Control Tasks</a></td>
#     <td>2019</td>
#     <td>EMNLP</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/76-5.html'>Quote</a>    <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/76-6.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>77</td>
#     <td><a href='https://www.aclweb.org/anthology/N16-1082.pdf'>Visualizing and Understanding Neural Models in NLP</a></td>
#     <td>2016</td>
#     <td>NAACL</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/77-4.html'>Quote</a>    <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/77-6.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>78</td>
#     <td><a href='https://www.aclweb.org/anthology/2020.acl-main.492.pdf'>Explaining Black Box Predictions and Unveiling Data Artifacts through Influence Functions</a></td>
#     <td>2020</td>
#     <td>ACL</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/78-11.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>79</td>
#     <td><a href='https://arxiv.org/pdf/1906.02361.pdf'>Explain Yourself! Leveraging Language Models for Commonsense Reasoning</a></td>
#     <td>2019</td>
#     <td>ACL</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/79-9.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>80</td>
#     <td><a href='https://www.aclweb.org/anthology/D19-1455.pdf'>Self-Assembling Modular Networks for Interpretable Multi-Hop Reasoning</a></td>
#     <td>2019</td>
#     <td>EMNLP</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/80-4.html'>Quote</a>    <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/80-8.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>81</td>
#     <td><a href='https://arxiv.org/pdf/1809.02701.pdf'>Trick Me If You Can: Human-in-the-Loop Generation of Adversarial Examples for Question Answering</a></td>
#     <td>2019</td>
#     <td>TACL</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/81-4.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>82</td>
#     <td><a href='https://arxiv.org/pdf/1906.05210.pdf'>Explore, Propose, and Assemble: An Interpretable Model for Multi-Hop Reading Comprehension</a></td>
#     <td>2019</td>
#     <td>ACL</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/82-6.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>83</td>
#     <td><a href='https://arxiv.org/pdf/1910.02610.pdf'>Multi-hop question answering via reasoning chains</a></td>
#     <td>2019</td>
#     <td>Arxiv</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/83-6.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>84</td>
#     <td><a href='https://arxiv.org/pdf/1910.14520.pdf'>Do Multi-hop Readers Dream of Reasoning Chains?</a></td>
#     <td>2019</td>
#     <td>ACL</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/84-6.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>85</td>
#     <td><a href='https://www.aclweb.org/anthology/P19-1488.pdf'>Interpretable Question Answering on Knowledge Bases and Text</a></td>
#     <td>2019</td>
#     <td>ACL</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/85-4.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>86</td>
#     <td><a href='https://arxiv.org/pdf/1809.03740.pdf'>Does it care what you asked? Understanding Importance of Verbs in Deep Learning QA System</a></td>
#     <td>2018</td>
#     <td>BlackboxNLP</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/86-4.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>87</td>
#     <td><a href='https://www.aclweb.org/anthology/D19-5313.pdf'>Chains-of-Reasoning at TextGraphs 2019 Shared Task: Reasoning over Chains of Facts for Explainable Multi-hop Inference</a></td>
#     <td>2019</td>
#     <td>EMNLP</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/87-6.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>88</td>
#     <td><a href='https://www.aclweb.org/anthology/W19-4113.pdf'>Learning to Explain: Answering Why-Questions via Rephrasing</a></td>
#     <td>2019</td>
#     <td>ACL</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/88-9.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>89</td>
#     <td><a href='https://arxiv.org/pdf/1809.03734.pdf'>How much should you ask? On the question structure in QA systems</a></td>
#     <td>2018</td>
#     <td>BlackboxNLP</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/89-4.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>90</td>
#     <td><a href='https://www.aclweb.org/anthology/D18-1259.pdf'>HotpotQA: A Dataset for Diverse, Explainable Multi-hop Question Answering</a></td>
#     <td>2018</td>
#     <td>EMNLP</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/90-4.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>91</td>
#     <td><a href='https://arxiv.org/pdf/1805.05492.pdf'>Did the Model Understand the Question?</a></td>
#     <td>2018</td>
#     <td>ACL</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/91-4.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>92</td>
#     <td><a href='https://arxiv.org/pdf/2005.01218.pdf'>Unsupervised Alignment-based Iterative Evidence Retrieval for Multi-hop Question Answering</a></td>
#     <td>2020</td>
#     <td>ACL</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/92-11.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>93</td>
#     <td><a href='https://www.aclweb.org/anthology/P19-1560.pdf'>Towards Explainable NLP: A Generative Explanation Framework for Text Classification</a></td>
#     <td>2019</td>
#     <td>ACL</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/93-9.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>94</td>
#     <td><a href='https://www.aclweb.org/anthology/W18-5111.pdf'>Interpreting Neural Network Hate Speech Classifiers</a></td>
#     <td>2018</td>
#     <td>EMNLP</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/94-4.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>95</td>
#     <td><a href='https://www.aclweb.org/anthology/D18-1508.pdf'>Interpretable emoji prediction via label-wise attention LSTMs</a></td>
#     <td>2018</td>
#     <td>EMNLP</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/95-4.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>96</td>
#     <td><a href='https://arxiv.org/pdf/1905.00563.pdf'>Investigating Robustness and Interpretability of Link Prediction via Adversarial Modifications</a></td>
#     <td>2019</td>
#     <td>NAACL</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/96-8.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>97</td>
#     <td><a href='https://arxiv.org/pdf/1905.09998.pdf'>Self-Critical Reasoning for Robust Visual Question Answering</a></td>
#     <td>2019</td>
#     <td>NeuIPS</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/97-4.html'>Quote</a>    <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/97-7.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>98</td>
#     <td><a href='https://arxiv.org/pdf/1801.09041.pdf'>Tell-and-answer: Towards explainable visual question answering using attributes and captions</a></td>
#     <td>2018</td>
#     <td>EMNLP</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/98-9.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>99</td>
#     <td><a href='https://arxiv.org/pdf/1906.00513.pdf'>Generating question relevant captions to aid visual question answering</a></td>
#     <td>2019</td>
#     <td>ACL</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/99-4.html'>Quote</a>    <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/99-9.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>100</td>
#     <td><a href='https://www.cs.utexas.edu/~ml/papers/rajani.vigil17.pdf'>Ensembling Visual Explanations for VQA</a></td>
#     <td>2017</td>
#     <td>Proceedings of the NIPS 2017 workshop on Visually-Grounded Interaction and Language (ViGIL)</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/100-4.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>101</td>
#     <td><a href='https://www.cs.utexas.edu/users/ml/papers/rajani.xai17.pdf'>Using Explanations to Improve Ensembling of Visual Question Answering Systems</a></td>
#     <td>2017</td>
#     <td>Proceedings of the IJCAI 2017 Workshop on Explainable Artificial Intelligence (XAI)</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/101-4.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>102</td>
#     <td><a href='https://arxiv.org/pdf/1612.08220.pdf'>Understanding neural networks through representation erasure</a></td>
#     <td>2016</td>
#     <td>Arxiv</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/102-4.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>103</td>
#     <td><a href='https://openaccess.thecvf.com/content_ECCV_2018/papers/Qing_Li_VQA-E_Explaining_Elaborating_ECCV_2018_paper.pdf'>Vqa-e: Explaining, elaborating, and enhancing your answers for visual questions</a></td>
#     <td>2018</td>
#     <td>ECCV</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/103-6.html'>Quote</a>    <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/103-9.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>104</td>
#     <td><a href='https://arxiv.org/pdf/1812.08951.pdf'>Analysis methods in neural language processing: A survey</a></td>
#     <td>2019</td>
#     <td>TACL</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/104-4.html'>Quote</a>    <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/104-5.html'>Quote</a>    <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/104-11.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>105</td>
#     <td><a href='https://www.aclweb.org/anthology/P18-1208.pdf'>Multimodal language analysis in the wild: Cmu-mosei dataset and interpretable dynamic fusion graph</a></td>
#     <td>2018</td>
#     <td>ACL</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/105-6.html'>Quote</a>    <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/105-13.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>106</td>
#     <td><a href='https://arxiv.org/pdf/1808.03894.pdf'>Interpreting recurrent and attention-based neural models: a case study on natural language inference</a></td>
#     <td>2018</td>
#     <td>EMNLP</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/106-4.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>107</td>
#     <td><a href='https://www.aclweb.org/anthology/P19-1284v1.pdf'>Interpretable neural predictions with differentiable binary variables</a></td>
#     <td>2019</td>
#     <td>ACL</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/107-4.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>108</td>
#     <td><a href='https://www.aclweb.org/anthology/N18-1146.pdf'>Deconfounded lexicon induction for interpretable social science</a></td>
#     <td>2018</td>
#     <td>NAACL</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/108-4.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>109</td>
#     <td><a href='https://www.aclweb.org/anthology/W19-5201.pdf'>Saliency-driven word alignment interpretation for neural machine translation</a></td>
#     <td>2019</td>
#     <td>ACL</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/109-4.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>110</td>
#     <td><a href='https://www.aclweb.org/anthology/W19-4016.pdf'>Explaining Simple Natural Language Inference</a></td>
#     <td>2019</td>
#     <td>ACL</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/110-9.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>111</td>
#     <td><a href='https://www.aclweb.org/anthology/W19-4816.pdf'>Modeling Paths for Explainable Knowledge Base Completion </a></td>
#     <td>2019</td>
#     <td>ACL</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/111-6.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>112</td>
#     <td><a href='https://pdfs.semanticscholar.org/7ad5/4b109a09925c5d8a55626b3221cbcdc1b019.pdf?_ga=2.86329368.1462757726.1607192920-2086044498.1602862197'>Guiding the Flowing of Semantics: Interpretable Video Captioning via POS Tag</a></td>
#     <td>2019</td>
#     <td>EMNLP</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/112-10.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>113</td>
#     <td><a href='https://arxiv.org/pdf/2004.13455.pdf'>DTCA: Decision Tree-based Co-Attention Networks for Explainable Claim Verification</a></td>
#     <td>2020</td>
#     <td>ACL</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/113-4.html'>Quote</a>    <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/113-6.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>114</td>
#     <td><a href='https://www.aclweb.org/anthology/2020.acl-main.717.pdf'>Learning Interpretable Relationships between Entities, Relations and Concepts via Bayesian Structure Learning on Open Domain Facts</a></td>
#     <td>2020</td>
#     <td>ACL</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/114-6.html'>Quote</a>    <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/114-10.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>115</td>
#     <td><a href='https://www.aclweb.org/anthology/2020.acl-srw.23.pdf'>Exploring Interpretability in Event Extraction: Multitask Learning of a Neural Event Classifier and an Explanation Decoder</a></td>
#     <td>2020</td>
#     <td>ACL</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/115-8.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>116</td>
#     <td><a href='https://arxiv.org/pdf/2010.07526.pdf'>Natural Language Rationales with Full-Stack Visual Reasoning: From Pixels to Semantic Frames to Commonsense Graphs</a></td>
#     <td>2020</td>
#     <td>EMNLP</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/116-9.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>117</td>
#     <td><a href='https://www.aclweb.org/anthology/W19-4826.pdf'>GEval: Tool for Debugging NLP Datasets and Models</a></td>
#     <td>2019</td>
#     <td>BlackboxNLP</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/117-4.html'>Quote</a>    <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/117-15.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>118</td>
#     <td><a href='https://homes.cs.washington.edu/~marcotcr/aaai18.pdf'>Anchors: High-Precision Model-Agnostic Explanations</a></td>
#     <td>2018</td>
#     <td>AAAI</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/118-8.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>119</td>
#     <td><a href='https://www.aclweb.org/anthology/P19-1205.pdf'>Improving Abstractive Document Summarization with Salient Information Modeling</a></td>
#     <td>2019</td>
#     <td>ACL</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/119-4.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>120</td>
#     <td><a href='https://arxiv.org/pdf/1905.11852.pdf'>Educe: Explaining model decisions through unsupervised concepts extraction</a></td>
#     <td>2019</td>
#     <td>Arxiv</td>
# ...
#     <td>2017</td>
#     <td>ICASSP (IEEE International Conference on Acous- tics, Speech and Signal Processing)</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/176-4.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>177</td>
#     <td><a href='https://www.aclweb.org/anthology/N19-1245.pdf'>MathQA: Towards interpretable math word problem solving with operation-based formalisms. </a></td>
#     <td>2019</td>
#     <td>NAACL</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/177-8.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>178</td>
#     <td><a href='https://www.aclweb.org/anthology/D19-1415.pdf'>Auditing deep learning processes through kernel-based explanatory models.</a></td>
#     <td>2019</td>
#     <td>EMNLP-IJCNLP</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/178-11.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>179</td>
#     <td><a href='https://www.aclweb.org/anthology/N19-4006.pdf'>Train, Sort, Explain: Learning to Diagnose Translation Models</a></td>
#     <td>2019</td>
#     <td>NAACL</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/179-4.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>180</td>
#     <td><a href='https://www.aclweb.org/anthology/P19-3023.pdf'>HEIDL: Learning Linguistic Expressions with Deep Learning and Human-in-the-Loop</a></td>
#     <td>2019</td>
#     <td>ACL</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/180-8.html'>Quote</a>    <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/180-11.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>181</td>
#     <td><a href='https://arxiv.org/pdf/1808.04127.pdf'>Learning Explanations from Language Data</a></td>
#     <td>2018</td>
#     <td>BlackboxNLP</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/181-4.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>182</td>
#     <td><a href='https://www.aclweb.org/anthology/W18-5418.pdf'>LISA: Explaining Recurrent Neural Network Judgments via Layer-wIse Semantic Accumulation and Example to Pattern Transformation</a></td>
#     <td>2018</td>
#     <td>BlackboxNLP</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/182-4.html'>Quote</a>    <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/182-7.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>183</td>
#     <td><a href='https://arxiv.org/pdf/1707.08852.pdf'>Detecting and Explaining Causes From Text For a Time Series Event</a></td>
#     <td>2017</td>
#     <td>EMNLP</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/183-6.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>184</td>
#     <td><a href='https://www.aclweb.org/anthology/D16-1216.pdf'>Interpreting neural networks to improve politeness comprehension.</a></td>
#     <td>2016</td>
#     <td>EMNLP</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/184-4.html'>Quote</a>    <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/184-7.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>185</td>
#     <td><a href='https://www.aclweb.org/anthology/W18-5403.pdf'>Explaining non-linear Classifier Decisions within Kernel-based Deep Architectures</a></td>
#     <td>2018</td>
#     <td>BlackboxNLP</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/185-11.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>186</td>
#     <td><a href='https://www.aclweb.org/anthology/P19-1331.pdf'>EditNTS: An Neural Programmer-Interpreter Model for Sentence Simplification through Explicit Editing</a></td>
#     <td>2019</td>
#     <td>ACL</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/186-4.html'>Quote</a>    <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/186-8.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>187</td>
#     <td><a href='https://www.aclweb.org/anthology/W18-5439.pdf'>Predicting and interpreting embeddings for out of vocabulary words in downstream tasks</a></td>
#     <td>2018</td>
#     <td>BlackboxNLP</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/187-4.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>188</td>
#     <td><a href='https://www.aclweb.org/anthology/N18-2110.pdf'>Detecting Linguistic Characteristics of Alzheimer’s Dementia by Interpreting Neural Models</a></td>
#     <td>2018</td>
#     <td>NAACL</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/188-4.html'>Quote</a>    <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/188-7.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>189</td>
#     <td><a href='https://www.aclweb.org/anthology/W18-5410.pdf'>Unsupervised Token-wise Alignment to Improve Interpretation of Encoder-Decoder Models</a></td>
#     <td>2018</td>
#     <td>BlackboxNLP</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/189-4.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>190</td>
#     <td><a href='https://www.aclweb.org/anthology/D19-1523.pdf'>Human-grounded Evaluations of Explanation Methods for Text Classification</a></td>
#     <td>2019</td>
#     <td>EMNLP-IJCNLP</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/190-4.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>191</td>
#     <td><a href='https://www.aclweb.org/anthology/N19-1420.pdf'>CNM: An Interpretable Complex-valued Network for Matching</a></td>
#     <td>2019</td>
#     <td>NAACL</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/191-4.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>192</td>
#     <td><a href='https://www.aclweb.org/anthology/C16-2032.pdf'>A Meaning-based English Math Word Problem Solver with Understanding, Reasoning and Explanation</a></td>
#     <td>2016</td>
#     <td>COLING</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/192-8.html'>Quote</a>    <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/192-9.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>193</td>
#     <td><a href='https://www.aclweb.org/anthology/P17-1015.pdf'>Program Induction by Rationale Generation: Learning to Solve and Explain Algebraic Word Problems</a></td>
#     <td>2017</td>
#     <td>ACL</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/193-4.html'>Quote</a>    <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/193-9.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>194</td>
#     <td><a href='https://arxiv.org/pdf/1802.05695.pdf'>Explainable Prediction of Medical Codes from Clinical Text</a></td>
#     <td>2018</td>
#     <td>NAACL</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/194-4.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>195</td>
#     <td><a href='https://www.aclweb.org/anthology/D17-2016.pdf'>Unsupervised, Knowledge-Free, and Interpretable Word Sense Disambiguation</a></td>
#     <td>2017</td>
#     <td>EMNLP</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/195-11.html'>Quote</a>    <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/195-14.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>196</td>
#     <td><a href='https://www.aclweb.org/anthology/D14-1052.pdf'>Explaining the Stars: Weighted Multiple-Instance Learning for Aspect-Based Sentiment Analysis</a></td>
#     <td>2014</td>
#     <td>EMNLP</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/196-11.html'>Quote</a>    <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/196-13.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>197</td>
#     <td><a href='https://www.aclweb.org/anthology/P18-1032.pdf'>Evaluating neural network explanation methods using hybrid documents and morphosyntactic agreement</a></td>
#     <td>2018</td>
#     <td>ACL</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/197-4.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>198</td>
#     <td><a href='https://www.research-collection.ethz.ch/bitstream/handle/20.500.11850/329832/2/N19-1038.pdf'>Learning interpretable negation rules via weak supervision at document level: A reinforcement learning approach</a></td>
#     <td>2019</td>
#     <td>NAACL</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/198-8.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>199</td>
#     <td><a href='https://www.aclweb.org/anthology/W18-5415.pdf'>Interpretable Neural Architectures for Attributing an Ad’s Performance to its Writing Style</a></td>
#     <td>2018</td>
#     <td>BlackboxNLP</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/199-4.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>200</td>
#     <td><a href='https://www.aclweb.org/anthology/N18-1146.pdf'>Deconfounded Lexicon Induction for Interpretable Social Science</a></td>
#     <td>2018</td>
#     <td>NAACL</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/200-10.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>201</td>
#     <td><a href='https://arxiv.org/pdf/1906.10924.pdf'>Interpretable Question Answering on Knowledge Bases and Text</a></td>
#     <td>2019</td>
#     <td>ACL</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/201-4.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>202</td>
#     <td><a href='https://arxiv.org/pdf/1904.10717.pdf'>Generating Token-Level Explanations for Natural Language Inference</a></td>
#     <td>2019</td>
#     <td>NAACL</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/202-4.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>203</td>
#     <td><a href='https://www.aclweb.org/anthology/W18-5427.pdf'>Iterative Recursive Attention Model for Interpretable Sequence Classification</a></td>
#     <td>2018</td>
#     <td>BlackboxNLP</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/203-4.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>204</td>
#     <td><a href='https://www.aclweb.org/anthology/P15-1055.pdf'>Learning to Explain Entity Relationships in Knowledge Graphs</a></td>
#     <td>2015</td>
#     <td>ACL</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/204-6.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>205</td>
#     <td><a href='https://www.aclweb.org/anthology/W18-5416.pdf'>Interpreting Neural Networks with Nearest Neighbors</a></td>
#     <td>2018</td>
#     <td>BlackboxNLP</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/205-4.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>206</td>
#     <td><a href='https://www.aclweb.org/anthology/P17-1088.pdf'>An Interpretable Knowledge Transfer Model for Knowledge Base Completion</a></td>
#     <td>2017</td>
#     <td>ACL</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/206-10.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>207</td>
#     <td><a href='https://www.aclweb.org/anthology/C18-1171.pdf'>An Interpretable Reasoning Network for Multi-Relation Question Answering</a></td>
#     <td>2018</td>
#     <td>COLING</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/207-10.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>208</td>
#     <td><a href='https://www.aclweb.org/anthology/C18-1058.pdf'>Exploiting Structure in Representation of Named Entities using Active Learning</a></td>
#     <td>2018</td>
#     <td>COLING</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/208-8.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>209</td>
#     <td><a href='https://openaccess.thecvf.com/content_ICCV_2017/papers/Hendricks_Localizing_Moments_in_ICCV_2017_paper.pdf'>Localizing Moments in Video With Natural Language</a></td>
#     <td>2017</td>
#     <td>ICCV</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/209-9.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>210</td>
#     <td><a href='https://www.aclweb.org/anthology/2020.emnlp-main.24.pdf'>FIND: Human-in-the-Loop Debugging Deep Text Classifiers</a></td>
#     <td>2020</td>
#     <td>EMNLP</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/210-13.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>211</td>
#     <td><a href='https://arxiv.org/pdf/2003.09772.pdf'>Invariant Rationalization</a></td>
#     <td>2020</td>
#     <td>ICML</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/211-4.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>212</td>
#     <td><a href='https://arxiv.org/pdf/2002.05867.pdf'>Transformers as Soft Reasoners over Language</a></td>
#     <td>2020</td>
#     <td>IJCAI</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/212-8.html'>Quote</a>    <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/212-9.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>213</td>
#     <td><a href='https://arxiv.org/pdf/1703.04730.pdf'>Understanding black-box predictions via influence functions</a></td>
#     <td>2017</td>
#     <td>ICML</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/213-11.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>214</td>
#     <td><a href='https://arxiv.org/abs/2008.11721'>How Useful Are the Machine-Generated Interpretations to General Users? A Human Evaluation on Guessing the Incorrectly Predicted Labels</a></td>
#     <td>2020</td>
#     <td>HCOMP</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/214-4.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>215</td>
#     <td><a href='https://arxiv.org/pdf/2001.09219.pdf'>Explainable Active Learning (XAL): An Empirical Study of How Local Explanations Impact Annotator Experience</a></td>
#     <td>2020</td>
#     <td>CSCW</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/215-4.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>216</td>
#     <td><a href='http://www.l3s.de/~gadiraju/publications/CSCW2019.pdf'>Dissonance Between Human and Machine Understanding</a></td>
#     <td>2019</td>
#     <td>CSCW</td>
# </tbody>  </tr>
# <tbody>  <tr>
#     <td>217</td>
#     <td><a href='https://arxiv.org/pdf/2007.10018.pdf'>Toward Machine-Guided, Human-Initiated Explanatory Interactive Learning</a></td>
#     <td>2020</td>
#     <td>TAILOR workshop at ECAI </td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/217-7.html'>Quote</a></tbody>  </tr>
# <tbody>  <tr>
#     <td>218</td>
#     <td><a href='https://arxiv.org/pdf/2009.09723.pdf'>Machine Guides, Human Supervises: Interactive Learning with Global Explanations</a></td>
#     <td>2020</td>
#     <td>Arxiv</td>
#     <td>{% include _icons/users.html %}<a class='page-link' href='/assets/files/form_quotes/218-7.html'>Quote</a></tbody>  </tr>
# </table>

# %%
# #!/usr/bin/python3
# # Run as: create-html-table.py {input-file-name}
# # The script requires 1 argument: the input file name.
# # It expects a comma-separated input file to parse into an html table,
# # and assumes that the column headers are located in the first row.

# # https://vidigest.com/2018/12/02/generating-an-html-table-from-file-data-using-python-3/
    
# import sys

# filein = open("test.txt", "r")
# data = filein.readlines()
# fileout = open("html-test-table.html", "w")

# # Create the table's column headers
# table = "<table>\n"
# header = data[0].split(",")
# table += "  <tr>\n"
# for column in header:
#     table += "    <th>{0}</th>\n".format(column.strip())
# table += "  </tr>\n"

# # Create the table's row data
# for line in data[1:]:
#     row = line.split(",")
    
#     table += "  <tr>\n"
#     for column in row:
#         table += "    <td>{0}</td>\n".format(column.strip())
#     table += "  </tr>\n"

# table += "</table>"

# fileout.writelines(table)
# fileout.close()
# filein.close()
